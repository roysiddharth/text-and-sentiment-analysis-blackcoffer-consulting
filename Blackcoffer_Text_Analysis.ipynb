# %% [markdown]
# # Downloading necessary dependencies

# %%
# # Uncomment during first run >>

# !pip install contractions
# import nltk
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')
# !pip install textstat
# Out:
# Collecting textstat
#   Downloading textstat-0.7.3-py3-none-any.whl (105 kB)
#      |████████████████████████████████| 105 kB 5.1 MB/s
# Collecting pyphen
#   Downloading pyphen-0.12.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 36.6 MB/s
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.12.0 textstat-0.7.3

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize # Can also use RegexpTokenizer
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer
import re
import contractions
from textstat.textstat import textstatistics
import string

# %% [markdown]
# # Data Manipulation

# %%
df = pd.read_csv('blackcoffer-consulting-file.csv')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
# Instantiating wordnet lemmatizer

lemma = WordNetLemmatizer()

# %%
# Instantiating the english language stopwords dictionary

stop_words = stopwords.words('english')

# %%
# Function to pre-process the text data
def text_prep(x: str) -> list:
     corp = str(x).lower()
     corp = contractions.fix(corp)
     corp = re.sub('[^a-zA-Z]+',' ', corp).strip() 
     tokens = word_tokenize(corp)
     words = [t for t in tokens if t not in stop_words]
     lemmatize = [lemma.lemmatize(w) for w in words]
     return lemmatize

# %%
# Applying the function on the data
preprocess_tag = [text_prep(i) for i in df['Text_Contents']]
df["preprocess_txt"] = preprocess_tag

# %% [markdown]
# # 1. Sentiment Analysis

# %% [markdown]
# ## Importing Opinion Lexicon of Positive and Negative words

# %%
file = open('negative-words.txt', 'r')
neg_words = file.read().split()
file = open('positive-words.txt', 'r')
pos_words = file.read().split()

# %%
df['num_words'] = df['preprocess_txt'].map(lambda x: len(x))

# %% [markdown]
# ## 1.1. Positive and Negative Scores

# %%
num_pos = df['preprocess_txt'].map(lambda x: len([i for i in x if i in pos_words]))
df['Positive'] = num_pos
num_neg = df['preprocess_txt'].map(lambda x: len([i for i in x if i in neg_words]))
df['Negative'] = num_neg

# %% [markdown]
# ## 1.2 Polarity Score

# %%
df['Polarity'] = round((df['Positive'] - df['Negative'])/(df['Positive'] + df['Negative'] + 0.000001), 2)

# %% [markdown]
# ## 1.3 Subjectivity Score

# %%
df['Subjectivity'] = round((df['Positive'] + df['Negative'])/(df['num_words'] + 0.000001), 2)

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 86     88.0  https://insights.blackcoffer.com/how-covid-19-...
# 8       9.0  https://insights.blackcoffer.com/how-big-data-...
# 134   136.0  https://insights.blackcoffer.com/advance-analy...
# 145   147.0  https://insights.blackcoffer.com/the-prospecti...
# 123   125.0  https://insights.blackcoffer.com/ensuring-grow...
#
#                                          Text_Contents  \
# 86    I would rather pay cash – Before COVID-19. I ...
# 8     Big data refers to large sets of unstructured...
# 134   Recent years have seen significant growth in ...
# 145   “As you sow, so you reap,” because “God watch...
# 123   The generally accepted\nsolution to economies...
#
#                                         preprocess_txt  num_words  Positive  \
# 86   [would, rather, pay, cash, covid, would, rathe...        302        32
# 8    [big, data, refers, large, set, unstructured, ...        807        84
# 134  [recent, year, seen, significant, growth, pers...        763        73
# 145  [sow, reap, god, watch, everything, often, won...        653        47
# 123  [generally, accepted, solution, economy, stagn...        610        38
#
#      Negative  Polarity  Subjectivity
# 86         13      0.42          0.15
# 8          26      0.53          0.14
# 134        27      0.46          0.13
# 145        26      0.29          0.11
# 123        26      0.19          0.10

# %% [markdown]
# # 2. Analysis of Readability

# %% [markdown]
# ## 2.1. Average Sentence Length

# %%
df['num_sentences'] = df['Text_Contents'].map(lambda x: len(sent_tokenize(x)))

# %%
df['avg_sentence_len'] = round(df['num_words']/df['num_sentences'], 1)

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 21     22.0  https://insights.blackcoffer.com/man-and-machi...
# 104   106.0  https://insights.blackcoffer.com/should-celebr...
# 71     73.0  https://insights.blackcoffer.com/how-voice-sea...
# 154   156.0  https://insights.blackcoffer.com/big-data-mark...
# 56     58.0  https://insights.blackcoffer.com/can-you-be-gr...
#
#                                          Text_Contents  \
# 21    Where is this disruptive technology taking us...
# 104   In today’s day and age of hyper-connectivity,...
# 71    Finding ways to make using the Internet easie...
# 154   Perfect information. First Degree Price Discr...
# 56    The word “leadership” can bring to mind a var...
#
#                                         preprocess_txt  num_words  Positive  \
# 21   [disruptive, technology, taking, u, take, leav...        653        68
# 104  [today, day, age, hyper, connectivity, celebri...        989        84
# 71   [finding, way, make, using, internet, easier, ...        462        62
# 154  [perfect, information, first, degree, price, d...        553        51
# 56   [word, leadership, bring, mind, variety, image...        224        42
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len
# 21         36      0.31          0.16             55              11.9
# 104        39      0.37          0.12             63              15.7
# 71         23      0.46          0.18             38              12.2
# 154        28      0.29          0.14             44              12.6
# 56          8      0.68          0.22             16              14.0

# %% [markdown]
# ## 2.2. Percentage of Complex Words

# %%
def syllables_count(text):
  return textstatistics().syllable_count(text)

# %%
def complex_words(text):
  diff_words_set = set()
  words = text
  for word in words:
    syllable_count = syllables_count(word)
    if syllable_count > 2:
      diff_words_set.add(word)
  return len(diff_words_set)

# %%
df['complex_words'] = df['preprocess_txt'].apply(lambda x: complex_words(x))

# %%
df['complex_words_prop'] = round((df['complex_words']/df['num_words']), 2)

# %%
df.sample(n = 5)
# Out:
#      URL_ID                                                URL  \
# 20     21.0  https://insights.blackcoffer.com/will-ai-repla...
# 83     85.0  https://insights.blackcoffer.com/what-is-the-r...
# 96     98.0  https://insights.blackcoffer.com/lessons-from-...
# 141   143.0  https://insights.blackcoffer.com/how-political...
# 129   131.0  https://insights.blackcoffer.com/challenges-an...
#
#                                          Text_Contents  \
# 20    “Machine intelligence is the last invention t...
# 83    Epidemics, in general, have both direct and i...
# 96    “The more you know about the past, the better...
# 141   Good governance is key to the growth and prog...
# 129   To begin with I shall first like to explain w...
#
#                                         preprocess_txt  num_words  Positive  \
# 20   [machine, intelligence, last, invention, human...        927        89
# 83   [epidemic, general, direct, indirect, cost, as...        652        38
# 96   [know, past, better, prepared, future, speak, ...        999        76
# 141  [good, governance, key, growth, progress, coun...        685        63
# 129  [begin, shall, first, like, explain, big, data...        583        69
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 20         44      0.34          0.14             76              12.2
# 83         69     -0.29          0.16             50              13.0
# 96        111     -0.19          0.19             66              15.1
# 141        28      0.38          0.13             38              18.0
# 129        56      0.10          0.21             65               9.0
#
#      complex_words  complex_words_prop
# 20             173                0.19
# 83             142                0.22
# 96             172                0.17
# 141            117                0.17
# 129            113                0.19

# %% [markdown]
# ## 2.3. Fog Index

# %%
df['Fog_index'] = 0.4 * (df['avg_sentence_len'] + df['complex_words_prop'])

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 121   123.0  https://insights.blackcoffer.com/impact-of-cov...
# 64     66.0  https://insights.blackcoffer.com/impacts-of-co...
# 21     22.0  https://insights.blackcoffer.com/man-and-machi...
# 59     61.0  https://insights.blackcoffer.com/is-perfection...
# 27     28.0  https://insights.blackcoffer.com/how-machines-...
#
#                                          Text_Contents  \
# 121   COVID-19: INTRODUCTION The Novel Coronavirus ...
# 64    Some vendors (fruit and vegetable sellers) be...
# 21    Where is this disruptive technology taking us...
# 59    What’s perfection really? Does every person e...
# 27    We all hear day in and day out that we amidst...
#
#                                         preprocess_txt  num_words  Positive  \
# 121  [covid, introduction, novel, coronavirus, covi...        995        59
# 64   [vendor, fruit, vegetable, seller, began, vent...        152        10
# 21   [disruptive, technology, taking, u, take, leav...        653        68
# 59   [perfection, really, every, person, expect, pe...        558        77
# 27   [hear, day, day, amidst, technological, revolu...        679        62
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 121        86     -0.19          0.15             74              13.4
# 64          9      0.05          0.12             11              13.8
# 21         36      0.31          0.16             55              11.9
# 59         30      0.44          0.19             76               7.3
# 27         40      0.22          0.15             57              11.9
#
#      complex_words  complex_words_prop  Fog_index
# 121            202                0.20      5.440
# 64              32                0.21      5.604
# 21             141                0.22      4.848
# 59              56                0.10      2.960
# 27             135                0.20      4.840

# %% [markdown]
# # 3. Average Number of Words Per Sentence

# %%
df['avg_words_per_sentence'] = round(df['num_words']/df['num_sentences'], 2)

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 132   134.0  https://insights.blackcoffer.com/traceability-...
# 0       1.0  https://insights.blackcoffer.com/how-is-login-...
# 56     58.0  https://insights.blackcoffer.com/can-you-be-gr...
# 24     25.0  https://insights.blackcoffer.com/how-machine-l...
# 28     29.0  https://insights.blackcoffer.com/ai-human-robo...
#
#                                          Text_Contents  \
# 132   The democratization of data access and usage ...
# 0     When people hear AI they often think about se...
# 56    The word “leadership” can bring to mind a var...
# 24    Machine learning techniques may have been use...
# 28    It’s the year 2060. An automaton in a Researc...
#
#                                         preprocess_txt  num_words  Positive  \
# 132  [democratization, data, access, usage, enterpr...        559        31
# 0    [people, hear, ai, often, think, sentient, rob...        408        27
# 56   [word, leadership, bring, mind, variety, image...        224        42
# 24   [machine, learning, technique, may, used, year...        381        51
# 28   [year, automaton, research, laboratory, say, s...        725        60
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 132        21      0.19          0.09             43              13.0
# 0          19      0.17          0.11             23              17.7
# 56          8      0.68          0.22             16              14.0
# 24         21      0.42          0.19             35              10.9
# 28         41      0.19          0.14             80               9.1
#
#      complex_words  complex_words_prop  Fog_index  avg_words_per_sentence
# 132            130                0.23      5.292                   13.00
# 0               73                0.18      7.152                   17.74
# 56              44                0.20      5.680                   14.00
# 24              51                0.13      4.412                   10.89
# 28             117                0.16      3.704                    9.06

# %% [markdown]
# # 4. Complex Word Count
#
# We can see from the data frame, the complex words count is already given in the `df['complex_words]` column.

# %%
df.head()
# Out:
#    URL_ID                                                URL  \
# 0     1.0  https://insights.blackcoffer.com/how-is-login-...
# 1     2.0  https://insights.blackcoffer.com/how-does-ai-h...
# 2     3.0  https://insights.blackcoffer.com/ai-and-its-im...
# 3     4.0  https://insights.blackcoffer.com/how-do-deep-l...
# 4     5.0  https://insights.blackcoffer.com/how-artificia...
#
#                                        Text_Contents  \
# 0   When people hear AI they often think about se...
# 1   With increasing computing power and more data...
# 2   If you were a fan of the 90’s film Clueless b...
# 3   Understanding exactly how data is ingested, a...
# 4   From the stone age to the modern world, from ...
#
#                                       preprocess_txt  num_words  Positive  \
# 0  [people, hear, ai, often, think, sentient, rob...        408        27
# 1  [increasing, computing, power, data, potential...        375        32
# 2  [fan, film, clueless, back, day, remember, pro...       1066       109
# 3  [understanding, exactly, data, ingested, analy...        246        17
# 4  [stone, age, modern, world, hunting, gathering...        398        43
#
#    Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 0        19      0.17          0.11             23              17.7
# 1        12      0.45          0.12             27              13.9
# 2        41      0.45          0.14             76              14.0
# 3         3      0.70          0.08             14              17.6
# 4        20      0.37          0.16             37              10.8
#
#    complex_words  complex_words_prop  Fog_index  avg_words_per_sentence
# 0             73                0.18      7.152                   17.74
# 1             89                0.24      5.656                   13.89
# 2            230                0.22      5.688                   14.03
# 3             64                0.26      7.144                   17.57
# 4             88                0.22      4.408                   10.76

# %% [markdown]
# # 5. Word Count
#
# We can see from the data frame, the word count is also already given in the `df['num_words']` column.

# %%
df.head()
# Out:
#    URL_ID                                                URL  \
# 0     1.0  https://insights.blackcoffer.com/how-is-login-...
# 1     2.0  https://insights.blackcoffer.com/how-does-ai-h...
# 2     3.0  https://insights.blackcoffer.com/ai-and-its-im...
# 3     4.0  https://insights.blackcoffer.com/how-do-deep-l...
# 4     5.0  https://insights.blackcoffer.com/how-artificia...
#
#                                        Text_Contents  \
# 0   When people hear AI they often think about se...
# 1   With increasing computing power and more data...
# 2   If you were a fan of the 90’s film Clueless b...
# 3   Understanding exactly how data is ingested, a...
# 4   From the stone age to the modern world, from ...
#
#                                       preprocess_txt  num_words  Positive  \
# 0  [people, hear, ai, often, think, sentient, rob...        408        27
# 1  [increasing, computing, power, data, potential...        375        32
# 2  [fan, film, clueless, back, day, remember, pro...       1066       109
# 3  [understanding, exactly, data, ingested, analy...        246        17
# 4  [stone, age, modern, world, hunting, gathering...        398        43
#
#    Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 0        19      0.17          0.11             23              17.7
# 1        12      0.45          0.12             27              13.9
# 2        41      0.45          0.14             76              14.0
# 3         3      0.70          0.08             14              17.6
# 4        20      0.37          0.16             37              10.8
#
#    complex_words  complex_words_prop  Fog_index  avg_words_per_sentence
# 0             73                0.18      7.152                   17.74
# 1             89                0.24      5.656                   13.89
# 2            230                0.22      5.688                   14.03
# 3             64                0.26      7.144                   17.57
# 4             88                0.22      4.408                   10.76

# %% [markdown]
# # 6. Syllable Count Per Word

# %%
df['syl_count'] = df['preprocess_txt'].apply(lambda x: syllables_count(" ".join(x)))

# %%
df['syl_per_word'] = df['syl_count']/df['num_words']

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 108   110.0  https://insights.blackcoffer.com/coronavirus-i...
# 22     23.0  https://insights.blackcoffer.com/in-future-or-...
# 70     72.0  https://insights.blackcoffer.com/human-rights-...
# 144   146.0  https://insights.blackcoffer.com/how-artificia...
# 165   167.0  https://insights.blackcoffer.com/role-big-data...
#
#                                          Text_Contents  \
# 108   Before jumping on the topic I would like to g...
# 22    In future or in upcoming years humans and mac...
# 70    Read on to discover what our robot, Athena, h...
# 144   Today we talk a lot about artificial intellig...
# 165   Can academia, researchers, decision makers an...
#
#                                         preprocess_txt  num_words  Positive  \
# 108  [jumping, topic, would, like, give, overview, ...        270        12
# 22   [future, upcoming, year, human, machine, going...        403        35
# 70   [read, discover, robot, athena, found, future,...         72         7
# 144  [today, talk, lot, artificial, intelligence, c...        845        86
# 165  [academia, researcher, decision, maker, policy...        828        74
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 108        13     -0.04          0.09             21              12.9
# 22         14      0.43          0.12             44               9.2
# 70          3      0.40          0.14              7              10.3
# 144        33      0.45          0.14             76              11.1
# 165        48      0.21          0.15             71              11.7
#
#      complex_words  complex_words_prop  Fog_index  avg_words_per_sentence  \
# 108             46                0.17      5.228                   12.86
# 22              74                0.18      3.752                    9.16
# 70              12                0.17      4.188                   10.29
# 144            150                0.18      4.512                   11.12
# 165            143                0.17      4.748                   11.66
#
#      syl_count  syl_per_word
# 108        533      1.974074
# 22         827      2.052109
# 70         125      1.736111
# 144       1776      2.101775
# 165       1752      2.115942

# %% [markdown]
# # 7. Personal Pronouns

# %%
def personal_pro(text):
  pronounRegex = re.compile(r'\b(I|we|my|ours|(?-i:us))\b',re.I)
  pronouns = pronounRegex.findall(text)
  return len(pronouns)

# %% [markdown]
# `(?-i:us)` is used as _in-line modifier group_ where the matching is CASE SENSITIVE. As a result, this matches only `us` not `US`.

# %%
df['personal_pronouns'] = df['Text_Contents'].apply(lambda x: personal_pro(x))

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 117   119.0  https://insights.blackcoffer.com/coronavirus-t...
# 127   129.0  https://insights.blackcoffer.com/big-data-anal...
# 99    101.0  https://insights.blackcoffer.com/why-scams-lik...
# 156   158.0  https://insights.blackcoffer.com/analytics-hel...
# 64     66.0  https://insights.blackcoffer.com/impacts-of-co...
#
#                                          Text_Contents  \
# 117   Since the creation of the EU, we have been th...
# 127   Quality and affordable healthcare is a vision...
# 99    India has been beset by financial scams since...
# 156   Demand forecasting is the most important phas...
# 64    Some vendors (fruit and vegetable sellers) be...
#
#                                         preprocess_txt  num_words  Positive  \
# 117  [since, creation, eu, many, challenge, worst, ...        135        11
# 127  [quality, affordable, healthcare, vision, gove...        651        47
# 99   [india, beset, financial, scam, since, indepen...       1288        72
# 156  [demand, forecasting, important, phase, fashio...        397        25
# 64   [vendor, fruit, vegetable, seller, began, vent...        152        10
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 117        16     -0.19          0.20             14               9.6
# 127        54     -0.07          0.16             65              10.0
# 99        115     -0.23          0.15             87              14.8
# 156         5      0.67          0.08             35              11.3
# 64          9      0.05          0.12             11              13.8
#
#      complex_words  complex_words_prop  Fog_index  avg_words_per_sentence  \
# 117             37                0.27      3.948                    9.64
# 127            118                0.18      4.072                   10.02
# 99             214                0.17      5.988                   14.80
# 156             87                0.22      4.608                   11.34
# 64              32                0.21      5.604                   13.82
#
#      syl_count  syl_per_word  personal_pronouns
# 117        268      1.985185                  8
# 127       1374      2.110599                  2
# 99        2589      2.010093                  6
# 156        868      2.186398                  1
# 64         306      2.013158                  0

# %% [markdown]
# # 8. Average Word Length

# %%
def text_len(text):
  text = ''.join(text)
  filtered = ''.join(filter(lambda x: x not in string.punctuation, text))
  words = [word for word in filtered.split() if word]
  avg = sum(map(len, words))/len(words)
  return avg

# %%
df['avg_word_len'] = df['Text_Contents'].map(lambda x: text_len(x))

# %%
df.sample(n=5)
# Out:
#      URL_ID                                                URL  \
# 105   107.0  https://insights.blackcoffer.com/how-prepared-...
# 166   168.0  https://insights.blackcoffer.com/sales-forecas...
# 82     84.0  https://insights.blackcoffer.com/what-is-the-r...
# 106   108.0  https://insights.blackcoffer.com/how-will-covi...
# 51     53.0  https://insights.blackcoffer.com/will-we-ever-...
#
#                                          Text_Contents  \
# 105   Frankly, no! The state of the public healthca...
# 166   Inventory planning is a fundamental part of r...
# 82    What is COVID 19 pandemic? On 31st December 2...
# 106   Every prophet of doom, unless he also happens...
# 51    Introduction The definition of consciousness ...
#
#                                         preprocess_txt  num_words  Positive  \
# 105  [frankly, state, public, healthcare, system, s...        454        27
# 166  [inventory, planning, fundamental, part, retai...        437        34
# 82   [covid, pandemic, st, december, novel, coronav...        347        21
# 106  [every, prophet, doom, unless, also, happens, ...        745        46
# 51   [introduction, definition, consciousness, cont...        968        50
#
#      Negative  Polarity  Subjectivity  num_sentences  avg_sentence_len  \
# 105        29     -0.04          0.12             32              14.2
# 166        20      0.26          0.12             28              15.6
# 82         34     -0.24          0.16             34              10.2
# 106        94     -0.34          0.19             55              13.5
# 51         68     -0.15          0.12             73              13.3
#
#      complex_words  complex_words_prop  Fog_index  avg_words_per_sentence  \
# 105             89                0.20      5.760                   14.19
# 166             99                0.23      6.332                   15.61
# 82              57                0.16      4.144                   10.21
# 106            137                0.18      5.472                   13.55
# 51             225                0.23      5.412                   13.26
#
#      syl_count  syl_per_word  personal_pronouns  avg_word_len
# 105        923      2.033040                  3      5.040816
# 166        964      2.205950                  0      5.628407
# 82         670      1.930836                  4      5.039216
# 106       1527      2.049664                  7      5.148823
# 51        2131      2.201446                 15      5.364541

# %% [markdown]
# # Formatting the Output Data Structure

# %%
df.columns
# Out:
# Index(['URL_ID', 'URL', 'Text_Contents', 'preprocess_txt', 'num_words',
#        'Positive', 'Negative', 'Polarity', 'Subjectivity', 'num_sentences',
#        'avg_sentence_len', 'complex_words', 'complex_words_prop', 'Fog_index',
#        'avg_words_per_sentence', 'syl_count', 'syl_per_word',
#        'personal_pronouns', 'avg_word_len'],
#       dtype='object')

# %%
df = df[['URL_ID', 'URL', 'Positive', 'Negative', 'Polarity', 'Subjectivity', 'avg_sentence_len', 'complex_words_prop', 'Fog_index', 'avg_words_per_sentence', 'complex_words', 'num_words', 'syl_per_word', 'personal_pronouns', 'avg_word_len']]

# %%
df.columns = ['URL_ID', 'URL', 'POSITIVE SCORE', 'NEGATIVE SCORE', 'POLARITY SCORE', 'SUBJECTIVITY SCORE', 'AVG SENTENCE LENGTH', 'PERCENTAGE OF COMPLEX WORDS', 'FOG INDEX', 'AVG NUMBER OF WORDS PER SENTENCE', 'COMPLEX WORD COUNT', 'WORD COUNT', 'SYLLABLE PER WORD', 'PERSONAL PRONOUNS', 'AVG WORD LENGTH']

# %%
df.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0     1.0  https://insights.blackcoffer.com/how-is-login-...              27
# 1     2.0  https://insights.blackcoffer.com/how-does-ai-h...              32
# 2     3.0  https://insights.blackcoffer.com/ai-and-its-im...             109
# 3     4.0  https://insights.blackcoffer.com/how-do-deep-l...              17
# 4     5.0  https://insights.blackcoffer.com/how-artificia...              43
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0              19            0.17                0.11                 17.7
# 1              12            0.45                0.12                 13.9
# 2              41            0.45                0.14                 14.0
# 3               3            0.70                0.08                 17.6
# 4              20            0.37                0.16                 10.8
#
#    PERCENTAGE OF COMPLEX WORDS  FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# 0                         0.18      7.152                             17.74
# 1                         0.24      5.656                             13.89
# 2                         0.22      5.688                             14.03
# 3                         0.26      7.144                             17.57
# 4                         0.22      4.408                             10.76
#
#    COMPLEX WORD COUNT  WORD COUNT  SYLLABLE PER WORD  PERSONAL PRONOUNS  \
# 0                  73         408           1.963235                  4
# 1                  89         375           2.101333                  2
# 2                 230        1066           2.095685                 13
# 3                  64         246           2.150407                  1
# 4                  88         398           2.087940                 21
#
#    AVG WORD LENGTH
# 0         5.097983
# 1         5.298555
# 2         5.367521
# 3         5.299528
# 4         4.990085

# %%
df.to_csv('Output-Data-Structure.csv', index = False)
